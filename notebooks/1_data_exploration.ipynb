# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/study_memory_data.csv")
df

# %%
df.info()

# %%
df.describe()

# %%
plt.figure(figsize=(8,5))
plt.scatter(df["days_since_last_revision"], df["memory_strength"])
plt.xlabel("Days Since Last Revision")
plt.ylabel("Memory Strength")
plt.title("Memory Decay Over Time")
plt.show()

# %%
correlation = df.corr(numeric_only=True)
correlation
